# %% [markdown]
# # Benchmark Consolidado — Modelos Supervisionados com Scikit-Learn
#
# Este notebook resume os resultados obtidos nos quatro estudos anteriores, comparando o desempenho de algoritmos clássicos de aprendizado supervisionado em tarefas de **classificação** e **regressão**.
#
# Datasets utilizados:
# - Classificação: Iris, Wine
# - Regressão: Diabetes, Boston Housing
#
# Modelos avaliados:
# - Classificação: Logistic Regression, Decision Tree, Random Forest, SVM, KNN, Naive Bayes, MLP
# - Regressão: Linear Regression, Decision Tree, Random Forest, SVR, KNN Regressor, Bayesian Ridge, MLP Regressor
#
# Métricas:
# - Classificação: Acurácia média e desvio (validação cruzada)
# - Regressão: R² médio e desvio (validação cruzada)
#
# Objetivo:
# - Consolidar os resultados em uma visão comparativa
# - Identificar os modelos mais robustos e versáteis
# - Refletir sobre generalização, estabilidade e adequação ao tipo de problema

# %% [markdown]
# # 🔹 1. Resultados de Classificação (Validação Cruzada)

# %%
import pandas as pd

classificacao = pd.DataFrame({
    'Modelo': ['Logistic Regression', 'Decision Tree', 'Random Forest', 'SVM', 'KNN', 'Naive Bayes', 'MLP'],
    'Iris (Acurácia)': [1.000, 0.967, 0.967, 0.980, 0.967, 0.953, 0.980],
    'Wine (Acurácia)': [0.989, 0.871, 0.972, 0.983, 0.955, 0.966, 0.983]
})
classificacao.set_index('Modelo', inplace=True)
classificacao
# Out:
#                      Iris (Acurácia)  Wine (Acurácia)
# Modelo
# Logistic Regression            1.000            0.989
# Decision Tree                  0.967            0.871
# Random Forest                  0.967            0.972
# SVM                            0.980            0.983
# KNN                            0.967            0.955
# Naive Bayes                    0.953            0.966
# MLP                            0.980            0.983

# %% [markdown]
# # 🔹 2. Resultados de Regressão (Validação Cruzada)

# %%
regressao = pd.DataFrame({
    'Modelo': ['Linear Regression', 'Decision Tree', 'Random Forest', 'SVR', 'KNN Regressor', 'Bayesian Ridge', 'MLP Regressor'],
    'Diabetes (R²)': [0.482, -0.094, 0.424, 0.147, 0.377, 0.481, None],
    'Boston (R²)': [1.000, 0.997, 0.999, 0.459, 0.738, 1.000, 0.857]
})
regressao.set_index('Modelo', inplace=True)
regressao
# Out:
#                    Diabetes (R²)  Boston (R²)
# Modelo
# Linear Regression          0.482        1.000
# Decision Tree             -0.094        0.997
# Random Forest              0.424        0.999
# SVR                        0.147        0.459
# KNN Regressor              0.377        0.738
# Bayesian Ridge             0.481        1.000
# MLP Regressor                NaN        0.857

# %% [markdown]
# # 🔹 3. Visualização Comparativa

# %%
import matplotlib.pyplot as plt

# Classificação
plt.figure(figsize=(10, 5))
plt.plot(classificacao.index, classificacao['Iris (Acurácia)'], marker='o', label='Iris')
plt.plot(classificacao.index, classificacao['Wine (Acurácia)'], marker='s', label='Wine')
plt.xticks(rotation=45)
plt.ylim(0.85, 1.02)
plt.title('Comparação de Acurácia Média — Classificação')
plt.ylabel('Acurácia')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# Regressão
plt.figure(figsize=(10, 5))
plt.plot(regressao.index, regressao['Diabetes (R²)'], marker='o', label='Diabetes')
plt.plot(regressao.index, regressao['Boston (R²)'], marker='s', label='Boston')
plt.xticks(rotation=45)
plt.ylim(-0.2, 1.05)
plt.title('Comparação de R² Médio — Regressão')
plt.ylabel('R²')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 📌 Reflexão Final
#
# Este benchmark mostrou que:
#
# - **Modelos lineares e MLP** se destacam tanto em classificação quanto em regressão, com alta acurácia e R².
# - **Random Forest** é versátil e robusto, com desempenho consistente em todos os cenários.
# - **Decision Tree** teve desempenho instável, especialmente em regressão (Diabetes).
# - **SVR e KNN** apresentaram limitações em datasets mais complexos ou ruidosos.
# - A **validação cruzada** foi essencial para revelar instabilidades que o hold-out não mostrou.
#
# **Conclusão**: Modelos simples e bem regularizados tendem a generalizar melhor. O projeto serve como base sólida para estudos futuros com tuning, pipelines e novos datasets.
